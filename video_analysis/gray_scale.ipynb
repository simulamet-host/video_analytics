# %%
import cv2
import glob
import matplotlib.pyplot as plt

# %%
_dir = "./images/2020-06-26_18-28-10_camera102/"
images_ = glob.glob(_dir + "/"+ '*.jpg' )

# %%
img = cv2.imread(_dir + 'frame0.jpg')
plt.imshow(img)
converted_img = cv2.cvtColor(img,  cv2.COLOR_BGR2GRAY)
plt.imshow(converted_img, cmap='gray')

# %%
img.shape
# Out:
# (240, 320, 3)

# %%
converted_img.shape
# Out:
# (240, 320)
